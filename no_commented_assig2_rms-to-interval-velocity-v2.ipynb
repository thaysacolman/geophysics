# %% [markdown]
# # RMS to interval velocity problem
#
# Forward mapping
#
# ![](equation1.png)

# %% [markdown]
# - $v_int$: interval velocity
# - $V_{rms}$: rms velocity
# - $w$:

# %% [markdown]
# inverse mapping
#
# ![image.png](attachment:2abc4f58-5cbe-4e0b-a508-28f3a155a268.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %% [markdown]
# ## define interval velocity
#
# $$v_{int} = v_0 + a \sin(2\pi f t)$$
#
# $$or$$
#
# $$v_{int} = v_0 + a \sin w$$

# %%
def interval_velocity_analytic(time, velocity0, amplitude, frequency, beta, beta0, omega): 
    """
    define our interval velocity as a harmonic function with amplitude (a), frequency (f), and base-value v0
    """
    return velocity0 + amplitude *np.sin(2*np.pi*frequency*time) + (beta * time)

# %% [markdown]
# - $B$: represents a constant rate of change of the interval velocity with respect to time.
# - $w$: Omega is how fast the velocity is oscillating, back and forth. It determines the rate at which the sine wave, completes its Cycles.

# %%
a = 50
v0 = 2000
b = 20
b0 = 0 
f = 2

# %%
n_times = 200 
max_time = 2
time = np.linspace(0, 2, n_times)
w = (2*np.pi*f*time)

# %%
vint = interval_velocity_analytic(time=time, velocity0=v0, amplitude=a, frequency=f, beta=b, beta0=b0, omega=w)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4)) 

ax.plot(time, vint)
ax.set_xlabel("time (s)")
ax.set_ylabel("interval velocity (m/s)")
ax.grid(alpha=0.5)

# %% [markdown]
# # forward problem
#
# $$V_{rms}^2 (t) = \frac{1}{t}\int_0^{t_{max}} v_{int}^2(u) du$$
#
# with
# - $v_{int} = v_0 + a \sin(2\pi f t)$
# - $v_{int} = v_0 + a \sin(\omega t)$
#
# ChatGPT
# I asked to  $$ v_{int} = \int_0^{t_{max}} (v_0 + a \sin(\omega t) + Bt)^2 $$
# integrate (v + a sin ⁡ ( ω t ) + B t )^2 from 0 to t
#
# ![](integral_chGPT.png)

# %% [markdown]
# <span style="color:blue">The following commented code was written by me. It generated a chart with two initial spikes, indicating a problem related to the sin or cos terms. I could not find the error in my code, which is why I used ChatGPT to review it. ChatGPT removed one of the terms containing np.cos from the integral, and the resulting graph now appears as expected. Although I don’t fully understand why the term was removed, I have kept this part of the code from ChatGPT because it worked as intended. </span>

# %%
def rms_velocity_analytic(time, velocity0, amplitude, frequency, beta): 

    inds_nonzero = time > 0 # in practice, you might want to pick a small number. it's write like this to avoid division by 0
    vrms2 = np.zeros_like(time) 
    # vrms2 = velocity0**2 * np.ones_like(time) 
    
    omega = 2 * np.pi * frequency
    
    
#    vrms2[inds_nonzero] = 1/time[inds_nonzero] * (
#        (
#           velocity0**2 * time[inds_nonzero]
#           - (2 * velocity0 * amplitude) / omega) * (np.cos(omega * time[inds_nonzero]) - 1)
#           + velocity0 * beta * time[inds_nonzero]**2
#           + (amplitude**2/2) * time[inds_nonzero]
#           - (amplitude**2 /(4 * omega)) * np.sin(2 * omega * time[inds_nonzero])
#           - (2* amplitude * beta * time[inds_nonzero] * (np.cos(omega * time[inds_nonzero])) / omega)
#           + (2 * amplitude * beta * (np.sin(omega * time[inds_nonzero])) / omega**2)
#           + ((beta**2) * (time[inds_nonzero]**3)/3)
#        )


    # Corrected integral terms according to chatgpt for B = 20
    vrms2[inds_nonzero] = (1 / time[inds_nonzero]) * (
        velocity0**2 * time[inds_nonzero]
        - (2 * velocity0 * amplitude / omega) * (np.cos(omega * time[inds_nonzero]) - 1)
        + (velocity0 * beta) * time[inds_nonzero]**2
        + (amplitude**2 / 2) * time[inds_nonzero]
        - (amplitude**2 / (4 * omega)) * np.sin(2 * omega * time[inds_nonzero])  
        + (2 * amplitude * beta / omega**2) * np.sin(omega * time[inds_nonzero])  # CHANGE: missing line 17 and slightly modifing line 18
        + (beta**2 / 3) * time[inds_nonzero]**3
        
    )
    
    vrms = np.sqrt(vrms2)  # Square root for RMS velocity
    vrms[~inds_nonzero] = velocity0
    return vrms

# %%
fig, ax = plt.subplots(1,1)

rms_velocity = rms_velocity_analytic(time, v0, a, f, b)

plt.plot(time, rms_velocity)

plt.title("B = 20")
plt.xlabel("Time (s)")
plt.ylabel("RMS Velocity (m/s)")
# Out:
# Text(0, 0.5, 'RMS Velocity (m/s)')

# %%
def rms_velocity_analytic(time, velocity0, amplitude, frequency, beta0): 

    inds_nonzero = time > 0 # in practice, you might want to pick a small number. it's write like this to avoid division by 0
    vrms2 = np.zeros_like(time) 
    # vrms2 = velocity0**2 * np.ones_like(time) 
    
    omega = 2 * np.pi * frequency
    
       
    vrms2[inds_nonzero] = (1 / time[inds_nonzero]) * (
        velocity0**2 * time[inds_nonzero]
        - (2 * velocity0 * amplitude / omega) * (np.cos(omega * time[inds_nonzero]) - 1)
        + (velocity0 * beta0) * time[inds_nonzero]**2
        + (amplitude**2 / 2) * time[inds_nonzero]
        - (amplitude**2 / (4 * omega)) * np.sin(2 * omega * time[inds_nonzero])  
        + (2 * amplitude * beta0 / omega**2) * np.sin(omega * time[inds_nonzero])  # CHANGE: missing line 17 and slightly modifing line 18
        + (beta0**2 / 3) * time[inds_nonzero]**3
    )

    vrms = np.sqrt(vrms2)  # Square root for RMS velocity
    vrms[~inds_nonzero] = velocity0
    return vrms

# %%
fig, ax = plt.subplots(1,1)

rms_velocity = rms_velocity_analytic(time, v0, a, f, b0)

plt.plot(time, rms_velocity, color="#FF5733")

plt.title("B = 0")
plt.xlabel("Time (s)")
plt.ylabel("RMS Velocity (m/s)")
# Out:
# Text(0, 0.5, 'RMS Velocity (m/s)')

# %% [markdown]
# # estimate vint from vrms2
#
# $$v_{int} = V_{RMS} \left(1 + \frac{2 t V'_{RMS}}{V_{RMS}}\right)^{1/2}$$

# %%
vrms = rms_velocity_analytic(time, v0, a, f, b)

# %%
def compute_vint_from_vrms(time, vrms):
    dt = np.diff(time)
    dvdt_approx = np.diff(vrms) / dt
    dvdt_approx = np.r_[0, dvdt_approx]  # forward difference
    vint_rec = vrms * np.sqrt(
        1 + (2 * time * dvdt_approx)/vrms
    )
    return vint_rec

# %%
vint_rec = compute_vint_from_vrms(time, vrms)

# %%
fig, ax = plt.subplots(1,1)

ax.plot(time, vint, label="true")
ax.plot(time, vint_rec, "o", label="recovered")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("Estimating vint from vrms2")
# Out:
# Text(0.5, 1.0, 'Estimating vint from vrms2')

# %% [markdown]
# # Inverting with a finite number of accurate data

# %%
decimate = 8 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.

t_obs = time[::decimate]
vrms_obs = vrms[::decimate]

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vrms, label="true vrms values")
ax.plot(t_obs, vrms_obs, "o", label="downsampled")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()

# %%
linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")

# %%
vrms_linear = linear_interpolation(time)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(t_obs, vrms_obs, "o", label="downsampled")
ax.plot(time, vrms, label="true vrms values")
ax.plot(time, vrms_linear, label="lineraly interpolated")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()

# %%
#linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")
#vrms_linear = linear_interpolation(time)

# %%
spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
#vint_linear_rec = compute_vint_from_vrms(time, vrms_linear)
vint_spline_rec = compute_vint_from_vrms(time, vrms_spline)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vint, label="true vrms value")
#ax.plot(time, vint_linear_rec, label="recovered (linear)")
ax.plot(time, vint_spline_rec, label="recovered (spline)")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()

# %% [markdown]
# ### recovering interval velocity (vint) from (vrms)

# %% [markdown]
# ####  Decimation level: 6

# %%
decimate = 6 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.

t_obs = time[::decimate]
vrms_obs = vrms[::decimate]

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vrms, label="true vrms values")
ax.plot(t_obs, vrms_obs, "o", label="downsampled")
ax.set_ylabel("RMS velocity (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ decimation level 6")
# Out:
# Text(0.5, 1.0, '$Vrms$ decimation level 6')

# %%
vint_linear_rec = compute_vint_from_vrms(time, vrms_linear)

# %%
#defining interpolations

linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

#arranging equation
vint_linear_rec = compute_vint_from_vrms(time, vrms_linear)
vint_spline_rec = compute_vint_from_vrms(time, vrms_spline)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vint, label="true vrms value")
ax.plot(time, vint_linear_rec, label="recovered (linear)")
ax.plot(time, vint_spline_rec, label="recovered (spline)")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("Recovering when $Vrms$ decimation level 6")
# Out:
# Text(0.5, 1.0, 'Recovering when $Vrms$ decimation level 6')

# %% [markdown]
# ####  Decimation level: 10

# %%
decimate = 10 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.

t_obs = time[::decimate]
vrms_obs = vrms[::decimate]

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vrms, label="true vrms values")
ax.plot(t_obs, vrms_obs, "o", label="downsampled")
ax.set_ylabel("RMS velocity (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ decimation level 10")
# Out:
# Text(0.5, 1.0, '$Vrms$ decimation level 10')

# %%
vint_linear_rec = compute_vint_from_vrms(time, vrms_linear)

# %%
#defining interpolations

linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

#arranging equation
vint_linear_rec = compute_vint_from_vrms(time, vrms_linear)
vint_spline_rec = compute_vint_from_vrms(time, vrms_spline)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vint, label="true vrms value")
ax.plot(time, vint_linear_rec, label="recovered (linear)")
ax.plot(time, vint_spline_rec, label="recovered (spline)")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("Recovering when $Vrms$ decimation level 10")
# Out:
# Text(0.5, 1.0, 'Recovering when $Vrms$ decimation level 10')

# %% [markdown]
# ####  Decimation level: 2

# %%
decimate = 2 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.

t_obs = time[::decimate]
vrms_obs = vrms[::decimate]

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vrms, label="true vrms values")
ax.plot(t_obs, vrms_obs, "o", label="downsampled")
ax.set_ylabel("RMS velocity (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ decimation level 2")
# Out:
# Text(0.5, 1.0, '$Vrms$ decimation level 2')

# %%
vint_linear_rec = compute_vint_from_vrms(time, vrms_linear)

# %%
#defining interpolations

linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

#arranging equation
vint_linear_rec = compute_vint_from_vrms(time, vrms_linear)
vint_spline_rec = compute_vint_from_vrms(time, vrms_spline)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vint, label="true vrms value")
ax.plot(time, vint_linear_rec, label="recovered (linear)")
ax.plot(time, vint_spline_rec, label="recovered (spline)")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("Recovering when $Vrms$ decimation level 2")
# Out:
# Text(0.5, 1.0, 'Recovering when $Vrms$ decimation level 2')

# %% [markdown]
# ###  Gaussian random noise in the data with standard deviations of 0.5 m/s

# %%
#assuming we're working with a gaussean distribuition

decimate = 8 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.
std = 0.5 #as higher as conservative

t_obs = time[::decimate]
noise_vector = std * np.random.randn(len(t_obs))
vrms_obs = vrms[::decimate] + noise_vector #np.random.randn plots numbers with the mean of z and the standard normal distribution (also known as standard deviation) of 1

# %%
plt.plot(t_obs, noise_vector, "o")
plt.xlabel("time (s)") 
plt.ylabel("Noise Level")

plt.show()

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vrms, label="true vrms values")
ax.plot(t_obs, vrms_obs, "o", label="downsampled")
#ax.plot(t_obs, noise_vector, label="noise")
ax.set_ylabel("RMS velocity (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ std = 0.5")
# Out:
# Text(0.5, 1.0, '$Vrms$ std = 0.5')

# %%
linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

# %%
spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(t_obs, vrms_obs, "o", label="downsampled")
#ax.plot(time, vrms_linear, label="linearly interpolated")
ax.plot(time, vrms, label="true vrms values")
ax.plot(time, vrms_spline, label="cubic spline interpolated")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ std = 0.5")
# Out:
# Text(0.5, 1.0, '$Vrms$ std = 0.5')

# %% [markdown]
# ###  Gaussian random noise in the data with standard deviations of 1 m/s

# %%
#assuming we're working with a gaussean distribuition

decimate = 8 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.
std = 1 #as higher as conservative

t_obs = time[::decimate]
noise_vector = std * np.random.randn(len(t_obs))
vrms_obs = vrms[::decimate] + noise_vector #np.random.randn plots numbers with the mean of z and the standard normal distribution (also known as standard deviation) of 1

# %%
plt.plot(t_obs, noise_vector, "o")
plt.xlabel("time (s)") 
plt.ylabel("Noise Level")

plt.show()

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vrms, label="true vrms values")
ax.plot(t_obs, vrms_obs, "o", label="downsampled")
ax.set_ylabel("RMS velocity (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ std = 1")
# Out:
# Text(0.5, 1.0, '$Vrms$ std = 1')

# %%
linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

# %%
spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(t_obs, vrms_obs, "o", label="downsampled")
#ax.plot(time, vrms_linear, label="linearly interpolated")
ax.plot(time, vrms, label="true vrms values")
ax.plot(time, vrms_spline, label="cubic spline interpolated")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ std = 1")
# Out:
# Text(0.5, 1.0, '$Vrms$ std = 1')

# %% [markdown]
# ###  Gaussian random noise in the data with standard deviations of 1.5 m/s

# %%
#assuming we're working with a gaussean distribuition

decimate = 8 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.
std = 1.5 #as higher as conservative

t_obs = time[::decimate]
noise_vector = std * np.random.randn(len(t_obs))
vrms_obs = vrms[::decimate] + noise_vector #np.random.randn plots numbers with the mean of z and the standard normal distribution (also known as standard deviation) of 1

# %%
vrms[::decimate].shape
noise_vector.shape
# Out:
# (25,)

# %%
plt.plot(t_obs, noise_vector, "o")
plt.xlabel("time (s)") 
plt.ylabel("Noise Level")

plt.show()

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(time, vrms, label="true vrms values")
ax.plot(t_obs, vrms_obs, "o", label="downsampled")
ax.set_ylabel("RMS velocity (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ std = 1.5")
# Out:
# Text(0.5, 1.0, '$Vrms$ std = 1.5')

# %%
linear_interpolation = interp1d(t_obs, vrms_obs, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

# %%
spline_interpolation = interp1d(t_obs, vrms_obs, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(t_obs, vrms_obs, "o", label="downsampled")
#ax.plot(time, vrms_linear, label="linearly interpolated")
ax.plot(time, vrms, label="true vrms values")
ax.plot(time, vrms_spline, label="cubic spline interpolated")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("$Vrms$ std = 1.5")
# Out:
# Text(0.5, 1.0, '$Vrms$ std = 1.5')

# %% [markdown]
# ### simpliging the model, by making $a$ = 0 ; cos($wt$) ; frequency = 2 ; std = 0

# %%
def interval_velocity_analytic(time, velocity0, amplitude, frequency, beta, omega): 
    """
    define our interval velocity as a harmonic function with amplitude (a), frequency (f), and base-value v0
    """
    return velocity0 + amplitude *np.sin(2*np.pi*frequency*time) + (beta * time)

# %%
#copying the inital model here and modifing parameters

a = 0  #previusly set as 50
v0 = 2000
b = 20
f = 2

n_times = 200 
max_time = 2
time = np.linspace(0, 2, n_times)
w = (2*np.pi*f*time)

vint = interval_velocity_analytic(time=time, velocity0=v0, amplitude=a, frequency=f, beta=b, omega=w)

# %%
def rms_velocity_analytic(time, velocity0, amplitude, frequency, beta): 

    inds_nonzero = time > 0 
    vrms2 = np.zeros_like(time) 
    
    
    omega = 2 * np.pi * frequency

    vrms2[inds_nonzero] = (1 / time[inds_nonzero]) * (
        velocity0**2 * time[inds_nonzero]
        - (2 * velocity0 * amplitude / omega) * (np.cos(omega * time[inds_nonzero]) - 1)
        + (velocity0 * beta) * time[inds_nonzero]**2
        + (amplitude**2 / 2) * time[inds_nonzero]
        - (amplitude**2 / (4 * omega)) * np.sin(2 * omega * time[inds_nonzero])  
        + (2 * amplitude * beta / omega**2) * np.sin(omega * time[inds_nonzero])
        + (beta**2 / 3) * time[inds_nonzero]**3
        
    )
    
    vrms = np.sqrt(vrms2)  # Square root for RMS velocity
    vrms[~inds_nonzero] = velocity0
    return vrms

# %%
vrms = rms_velocity_analytic(time, v0, a, f, b)

# %%
#assuming we're working with a gaussean distribuition

decimate = 8 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.
std = 1 #as higher as conservative
frequency = 2
omega = 2 * np.pi * frequency

t_obs = time[::decimate]
noise_vector2 = std * np.cos(omega * t_obs)
vrms_obs2 = vrms[::decimate] + noise_vector2

# %%
plt.plot(t_obs, noise_vector2, "o")
plt.xlabel("time (s)") 
plt.ylabel("Noise Level")
plt.show()

# %%
fig, ax = plt.subplots(1,1)

rms_velocity = rms_velocity_analytic(time, v0, a, f, b)

plt.plot(time, rms_velocity)
ax.plot(t_obs, vrms_obs2, "o", label="downsampled")
ax.plot(time, vrms, label="true vrms velocity")
plt.title("$a$ = 0, cos($wt$), freq = 2")
plt.xlabel("Time (s)")
plt.ylabel("VRMS velocity (m/s)")

ax.legend()

# %%
spline_interpolation = interp1d(t_obs, vrms_obs2, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
linear_interpolation = interp1d(t_obs, vrms_obs2, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(t_obs, vrms_obs2, "o", label="downsampled")
ax.plot(time, vrms_linear, label="linearly interpolated")
ax.plot(time, vrms, label="true vrms values")
ax.plot(time, vrms_spline, label="cubic spline interpolated")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("Recovering Vrms")
# Out:
# Text(0.5, 1.0, 'Recovering Vrms')

# %% [markdown]
# ### simpliging the model, by making $a$ = 0 ; cos($wt$) ; frequency = 20 ; std = 1.5

# %%
def interval_velocity_analytic(time, velocity0, amplitude, frequency, beta, omega): 
    """
    define our interval velocity as a harmonic function with amplitude (a), frequency (f), and base-value v0
    """
    return velocity0 + amplitude *np.cos(2*np.pi*frequency*time) + (beta * time)

# %%
#copying the inital model here and modifing parameters

a = 0  #previusly set as 50
v0 = 2000
b = 20
f = 20

n_times = 200 
max_time = 2
time = np.linspace(0, 2, n_times)
w = (2*np.pi*f*time)

vint = interval_velocity_analytic(time=time, velocity0=v0, amplitude=a, frequency=f, beta=b, omega=w)

# %%
def rms_velocity_analytic(time, velocity0, amplitude, frequency, beta): 

    inds_nonzero = time > 0 
    vrms2 = np.zeros_like(time) 
    
    
    omega = 2 * np.pi * frequency

    vrms2[inds_nonzero] = (1 / time[inds_nonzero]) * (
        velocity0**2 * time[inds_nonzero]
        - (2 * velocity0 * amplitude / omega) * (np.cos(omega * time[inds_nonzero]) - 1)
        + (velocity0 * beta) * time[inds_nonzero]**2
        + (amplitude**2 / 2) * time[inds_nonzero]
        - (amplitude**2 / (4 * omega)) * np.sin(2 * omega * time[inds_nonzero])  
        + (2 * amplitude * beta / omega**2) * np.sin(omega * time[inds_nonzero])
        + (beta**2 / 3) * time[inds_nonzero]**3
        
    )
    
    vrms = np.sqrt(vrms2)  # Square root for RMS velocity
    vrms[~inds_nonzero] = velocity0
    return vrms

# %%
vrms = rms_velocity_analytic(time, v0, a, f, b)

# %%
#assuming we're working with a gaussean distribuition

decimate = 8 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.
std = 1 #as higher as conservative
frequency = 20
omega = 2 * np.pi * frequency

t_obs = time[::decimate]
noise_vector2 = std * np.sin(omega * t_obs)
vrms_obs2 = vrms[::decimate] + noise_vector2

# %%
plt.plot(t_obs, noise_vector2, "o")
plt.xlabel("time (s)") 
plt.ylabel("Noise Level")
plt.show()

# %%
fig, ax = plt.subplots(1,1)

rms_velocity = rms_velocity_analytic(time, v0, a, f, b)

plt.plot(time, rms_velocity)
ax.plot(t_obs, vrms_obs2, "o", label="downsampled")
ax.plot(time, vrms, label="true vrms velocity")
plt.title("$a$ = 0, cos($wt$), freq = 20")
plt.xlabel("Time (s)")
plt.ylabel("VRMS velocity (m/s)")

ax.legend()

# %%
spline_interpolation = interp1d(t_obs, vrms_obs2, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
linear_interpolation = interp1d(t_obs, vrms_obs2, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(t_obs, vrms_obs2, "o", label="downsampled")
ax.plot(time, vrms_linear, label="linearly interpolated")
ax.plot(time, vrms, label="true vrms values")
ax.plot(time, vrms_spline, label="cubic spline interpolated")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("Recovering Vrms")
# Out:
# Text(0.5, 1.0, 'Recovering Vrms')

# %% [markdown]
# ### simpliging the model, by making $a$ = 0 ; sin($wt$) ; frequency = 20 ; std = 1.5

# %%
def interval_velocity_analytic(time, velocity0, amplitude, frequency, beta, omega): 
    """
    define our interval velocity as a harmonic function with amplitude (a), frequency (f), and base-value v0
    """
    return velocity0 + amplitude *np.sin(2*np.pi*frequency*time) + (beta * time)

# %%
#copying the inital model here and modifing parameters

a = 0  #previusly set as 50
v0 = 2000
b = 20
f = 20

n_times = 200 
max_time = 2
time = np.linspace(0, 2, n_times)
w = (2*np.pi*f*time)

vint = interval_velocity_analytic(time=time, velocity0=v0, amplitude=a, frequency=f, beta=b, omega=w)

# %%
def rms_velocity_analytic(time, velocity0, amplitude, frequency, beta): 

    inds_nonzero = time > 0 
    vrms2 = np.zeros_like(time) 
    
    
    omega = 2 * np.pi * frequency

    vrms2[inds_nonzero] = (1 / time[inds_nonzero]) * (
        velocity0**2 * time[inds_nonzero]
        - (2 * velocity0 * amplitude / omega) * (np.cos(omega * time[inds_nonzero]) - 1)
        + (velocity0 * beta) * time[inds_nonzero]**2
        + (amplitude**2 / 2) * time[inds_nonzero]
        - (amplitude**2 / (4 * omega)) * np.sin(2 * omega * time[inds_nonzero])  
        + (2 * amplitude * beta / omega**2) * np.sin(omega * time[inds_nonzero])
        + (beta**2 / 3) * time[inds_nonzero]**3
        
    )
    
    vrms = np.sqrt(vrms2)  # Square root for RMS velocity
    vrms[~inds_nonzero] = velocity0
    return vrms

# %%
vrms = rms_velocity_analytic(time, v0, a, f, b)

# %%
#assuming we're working with a gaussean distribuition

decimate = 8 #by increasing this number we see fewer datapoints and the linear interpolation starts to feet less the original data.
std = 1 #as higher as conservative
frequency = 20
omega = 2 * np.pi * frequency

t_obs = time[::decimate]
noise_vector2 = std * np.sin(omega * t_obs)
vrms_obs2 = vrms[::decimate] + noise_vector2

# %%
plt.plot(t_obs, noise_vector2, "o")
plt.xlabel("time (s)") 
plt.ylabel("Noise Level")
plt.show()

# %%
fig, ax = plt.subplots(1,1)

rms_velocity = rms_velocity_analytic(time, v0, a, f, b)

plt.plot(time, rms_velocity)
ax.plot(t_obs, vrms_obs2, "o", label="downsampled")
ax.plot(time, vrms, label="true vrms velocity")
plt.title("$a$ = 0, sin($wt$), freq = 20")
plt.xlabel("Time (s)")
plt.ylabel("VRMS velocity (m/s)")

ax.legend()

# %%
spline_interpolation = interp1d(t_obs, vrms_obs2, kind="cubic", fill_value="extrapolate")
vrms_spline = spline_interpolation(time)

# %%
linear_interpolation = interp1d(t_obs, vrms_obs2, kind="linear", fill_value="extrapolate")
vrms_linear = linear_interpolation(time)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(t_obs, vrms_obs2, "o", label="downsampled")
ax.plot(time, vrms_linear, label="linearly interpolated")
ax.plot(time, vrms, label="true vrms values")
ax.plot(time, vrms_spline, label="cubic spline interpolated")
ax.set_ylabel("$v_{int}$ (m/s)")
ax.set_xlabel("time (s)")
ax.legend()
plt.title("Recovering Vrms")
# Out:
# Text(0.5, 1.0, 'Recovering Vrms')
